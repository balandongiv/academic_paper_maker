# %%
import os
from download_pdf.database_preparation import combine_scopus_csvs_to_excel
# from personal_note.tutorial import output_excel

main_folder=r"G:\My Drive\research_related\ear_eog"
# folder_path = r"C:\Users\balan\OneDrive - ums.edu.my\research_related\corona_discharge\database\scopus"
folder_path=os.path.join(main_folder,'database','scopus')
output_excel =  os.path.join(main_folder,'database','combined_filtered.xlsx')
# output_excel =  r"C:\Users\balan\OneDrive - ums.edu.my\research_related\corona_discharge\database\combined_filtered.xlsx"

combine_scopus_csvs_to_excel(folder_path, output_excel)
# Out:
# ['Multidisciplinary Digital Publishing Institute (MDPI)'
#  'John Wiley and Sons Inc' 'Springer' 'MDPI'
#  'American Scientific Publishing Group (ASPG)' 'Little Lion Scientific'
#  "Taylor's University" 'Institute of Advanced Engineering and Science'
#  'Taylor and Francis Ltd.' 'Science and Information Organization'
#  'Institute of Electrical and Electronics Engineers Inc.'
#  'Mary Ann Liebert Inc.' 'Elsevier Ltd'
#  'Springer Science and Business Media Deutschland GmbH' 'Springer Nature'
#  'ALife Robotics Corporation Ltd'
#  'Faculty of Engineering, University of Kragujevac'
#  'Dove Medical Press Ltd' 'Tech Science Press' 'River Publishers'
#  'Hindawi Limited' 'North Atlantic University Union NAUN'
#  'SAGE Publications Ltd' 'World Scientific' 'Oxford University Press'
#  'Nature Research' 'Institution of Engineering and Technology'
#  'IEEE Computer Society' 'Research Trend' 'Elsevier B.V.' 'MDPI AG'
#  'International Association of Online Engineering' 'W.B. Saunders Ltd'
#  'Institute of Advanced Scientific Research, Inc.'
#  'Iranian Journal of Public Health'
#  'Blue Eyes Intelligence Engineering and Sciences Publication'
#  'Korean Institute of Industrial Engineers'
#  'Institute of Electronics, Information and Communication, Engineers, IEICE'
#  'International Information and Engineering Technology Association'
#  'American Institute of Mathematical Sciences'
#  'Science and Engineering Research Support Society'
#  'Public Library of Science' 'SAGE Publications Inc.' 'SPIE' nan
#  'Chinese Fuzzy Systems Association' 'Taylor and Francis Inc.' 'Routledge'
#  'Springer New York LLC' 'Carbon Magics Ltd' 'PeerJ Inc.'
#  'West University of Timisoara' 'KeAi Communications Co.'
#  'Association for Computing Machinery' 'Lippincott Williams and Wilkins'
#  'Scibulcom Ltd.' 'Frontiers Media SA'
#  'Faculty of Engineering, Universitas Indonesia' 'Elsevier Ireland Ltd'
#  'John Wiley and Sons Ltd' 'Springer Science and Business Media B.V.'
#  'American Academy of Family Physicians' 'BMJ Publishing Group'
#  'Inderscience Publishers' 'Bellwether Publishing, Ltd.'
#  'International Journal of Scientific and Technology Research'
#  'Tehran University of Medical Sciences' 'IOP Publishing Ltd'
#  'Silesian University of Technology'
#  'Indian Journal of Public Health Research and Development'
#  'Elsevier Inc.' 'American Scientific Publishers' 'ICIC International'
#  'ASTES Publishers' 'Blackwell Publishing Ltd' 'W.B. Saunders'
#  'Institute of Medico-Legal Publications'
#  'American Academy of Sleep Medicine' 'Springer International Publishing'
#  'Springer Verlag' 'Sciendo' 'Ethiopian Public Health Association'
#  'Sharif University of Technology' 'Wolters Kluwer Medknow Publications'
#  'World Scientific and Engineering Academy and Society'
#  'Korean Society of Automotive Engineers' 'Elsevier'
#  'National Academy of Sciences'
#  'Isfahan University of Medical Sciences(IUMS)' 'Editorial Department'
#  'Research Journal of Pharmaceutical, Biological and Chemical Sciences'
#  'Current Medicine Group LLC 1' 'Cambridge University Press'
#  'Blackwell Publishing Inc.' 'Elsevier Science Ltd'
#  'Finnish Institute of Occupational Health' 'Elsevier Sci B.V.'
#  'Adis International Ltd' 'Academic Press Inc.'
#  'American Academy of Pediatrics' 'Seventh Sense Research Group' 'Adis'
#  'Slovak University of Technology in Bratislava'
#  'Scientific Association for Infocommunications' 'Aracne Editrice'
#  'University of Portsmouth' 'De Gruyter Open Ltd'
#  'Politeknik Negeri Padang' 'OAE Publishing Inc.'
#  'Auricle Global Society of Education and Research'
#  'Society of Forensic Toxicologists' 'Sumy State University'
#  'Salehan Institute of Higher Education'
#  'International Islamic University Malaysia-IIUM' 'Frontiers Media S.A.'
#  'Chaoyang University of Technology' 'Emerald Group Holdings Ltd.'
#  'University of Bahrain' 'Riga Technical University' 'Mosby Inc.'
#  'IAEME Publication' 'Technology Center'
#  'MDPI Multidisciplinary Digital Publishing Institute' 'Elsevier GmbH'
#  'Associacao Iberica de Sistemas e Tecnologias de Informacao'
#  'Advanced Scientific Research' 'Institute of Physics Publishing'
#  'Slack Incorporated' 'Gioacchino Onorati Editore' 'ECTI Association'
#  'Nature Publishing Group' 'IOS Press' 'Asian Research Publishing Network'
#  'International Society for Computers and Their Applications'
#  'Universitas Ahmad Dahlan' 'Korean Society for Internet Information'
#  'Science Publications' 'Science Publishing Corporation Inc'
#  'Oriental Scientific Publishing Company' 'Balkan Society of Geometers'
#  'Bentham Science Publishers' 'Dove Medical Press Ltd.'
#  'ICIC Express Letters Office'
#  'Institute of Electrical and Electronics Engineers'
#  'Walter de Gruyter GmbH' 'Hogrefe Verlag GmbH & Co. KG'
#  'Associated Professional Sleep Societies,LLC' 'Frontiers Media S. A'
#  'Health Hamadan University of Medical Sciences' 'SpringerOpen'
#  'Ukrmetallurginform Scientific and Technical Agency Ltd'
#  'Natural Sciences Publishing Co.' 'Kluwer Academic Publishers'
#  'Informa Healthcare' 'SPB Pharma Society' 'Medknow Publications'
#  'Centre for Environment Social and Economic Research'
#  'Nofer Institute of Occupational Medicine' 'Elsevier Masson SAS'
#  'Polish Academy of Sciences'
#  'National Institute for R and D in Informatics' 'Elsevier BV'
#  'Institute of Electrical Engineers of Japan'
#  'International Society of Automation' 'Taylor & Francis Ltd']
# ['mdpi' 'wiley' 'springer' 'other' 'iaescore_ijece' 'tandfonline' 'ieee'
#  'sciencedirect' 'techscience' 'biorxiv' 'sagepub_journals'
#  'worldscientific' 'oup' 'nature' 'iet' 'plos_journals' 'acm'
#  'lww_journals' 'sciencepubco' 'frontiers' 'bmj' 'inderscience'
#  'iopscience' 'cambridge' 'academicpress' 'degruyter' 'iospress_content'
#  'neuroquantology' 'sharif_scientiairanica']
# Combined file has been saved to: G:\My Drive\research_related\ear_eog\database\combined_filtered.xlsx

# %% [markdown]
# # Combine to master listvv
#
#
# When use the agent_name="section_sorter", sometime, the section ID is not matched with the master json file.
# This make it difficult to compile the childrent json(i.e., all the json from llm) into master file
#
# This code use different strategy to match the section ID with the master json file.
# `C:\Users\balan\IdeaProjects\academic_paper_maker\research_filter\section_sorter_to_json_masterfile.py`
